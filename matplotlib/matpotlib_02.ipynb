# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
# for current_ax in axes:
#     current_ax.plot(x,y)

axes[0].plot(y,x)
axes[0].set_title("First plot")

axes[1].plot(x,y)
axes[1].set_title("Second plot")

plt.tight_layout()

# %%
import numpy as np
x=np.linspace(0,5,11)
y=2**x

# %%
axes[0].plot(y,x)
axes[0].set_title("First plot")
# Out:
# Text(0.5, 1.0, 'First plot')

# %% [markdown]
# ## Figure size and dpi

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# ## Save figure to file

# %%
fig.savefig('my_picture_200.png',dpi=200)
fig.savefig('my_picture_100.png',dpi=100)

# %% [markdown]
# ## Legends

# %%
fig = plt.figure()
ax= fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_ylabel('Y label')
ax.set_xlabel('X label')
# Out:
# Text(0.5, 0, 'X label')

# %%
fig = plt.figure()
ax= fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X squared")
ax.plot(x,x**3,label="Y Cubed")

ax.set_title('Title')
ax.legend(loc=(0.1,0.1))
